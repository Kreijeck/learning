# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread("bild.jpg")

# %%
i = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, "gray")

# %%
classifier = cv2.CascadeClassifier("../data/)
